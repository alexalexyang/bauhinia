# %% [markdown]
# # Stock types
#
# Addictions:
# - Things people crave
# - Crisps
# - Chocolates
#
# Staples:
# - Things people need
# - Supermarkets
# - Apple
#
# Luxury
# - Things with an economically untouchable clientele

# %%
# Changes to modules not reflected in this notebook without this
# %load_ext autoreload
# %autoreload

from etl import (
    get_stock_data,
)

from calc import (
    calc_line_params,
    visualise_dataframes
)

from financials import (
    get_all_earnings_info,
    show_earnings_info
)

import time
import json

# %%
# Tickers I am keeping an eye on
tickers = json.load(open("kiv.json"))

# https://finance.yahoo.com/screener/predefined/undervalued_large_caps/

# %%
today = time.strftime("%Y-%m-%d")
data_dir = f'kiv_{today}'
period = '3mo'
interval = '1d'
ma_and_std_window = 20

multi_df = get_stock_data(tickers, period, interval, ma_and_std_window, today, data_dir)
# Out:
# Today's data not found in data dir. Getting new data.
# [*********************100%%**********************]  22 of 22 completed
# 3 Failed downloads:
# ['TSMC', 'AXFO', 'CLAS B']: Exception('%ticker%: No data found, symbol may be delisted')

# %%
for ticker, df in multi_df.items():
    coeff, intercept, fitted_line = calc_line_params(df)
    df["Fitted"] = fitted_line

visualise_dataframes(multi_df, period, ma_and_std_window)
# Out:
# /Users/alex.yang/Documents/GitHub/bauhinia2/nb/calc.py:73: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, ax = plt.subplots(figsize=(12,6))

# %%
info_list = get_all_earnings_info(multi_df)
show_earnings_info(info_list)
# Out:
#            period  strongBuy  buy  hold  sell  strongSell
# symbol row
# FSLR   0       0m          3    6     8     0           0
# symbol: FSLR
# trailingPE: 38.637188
# forwardPE: 12.763295
# pegRatio: 0.32
# trailingPegRatio: None
#            period  strongBuy  buy  hold  sell  strongSell
# symbol row
# NEE    0       0m          5    8     2     0           0
# symbol: NEE
# trailingPE: 15.765172
# forwardPE: 17.573528
# pegRatio: 2.34
# trailingPegRatio: 2.4073
#            period  strongBuy  buy  hold  sell  strongSell
# symbol row
# AAPL   0       0m         11   21     6     0           0
# symbol: AAPL
# trailingPE: 31.530947
# forwardPE: 29.830511
# pegRatio: 5.83
# trailingPegRatio: 2.3206
#            period  strongBuy  buy  hold  sell  strongSell
# symbol row
# MSFT   0       0m         14   13     6     0           1
# symbol: MSFT
# trailingPE: 36.226303
# forwardPE: 31.906303
# pegRatio: 2.63
# trailingPegRatio: 2.2344
#            period  strongBuy  buy  hold  sell  strongSell
# symbol row
# GOOG   0       0m          2    3     0     0           0
# symbol: GOOG
# trailingPE: 27.340998
# forwardPE: 23.707642
# pegRatio: 1.55
# trailingPegRatio: 1.3441
#            period  strongBuy  buy  hold  sell  strongSell
# symbol row
# AMZN   0       0m         15   28     3     1           0
# symbol: AMZN
# trailingPE: 80.74737
# forwardPE: 47.061348
# pegRatio: 0.8
# trailingPegRatio: 2.4906
#            period  strongBuy  buy  hold  sell  strongSell
# symbol row
# NVDA   0       0m          7   14    15     1           1
# symbol: NVDA
# trailingPE: 64.50462
# forwardPE: 26.26681
# pegRatio: 0.47
# trailingPegRatio: 0.4905
#            period  strongBuy  buy  hold  sell  strongSell
# symbol row
# PYPL   0       0m         14   18    12     0           0
# symbol: PYPL
# trailingPE: 18.459702
# forwardPE: 12.318726
# pegRatio: 0.83
# trailingPegRatio: 0.5171
#            period  strongBuy  buy  hold  sell  strongSell
# symbol row
# NFLX   0       0m         11   14    14     1           1
# symbol: NFLX
# trailingPE: 48.53041
# forwardPE: 33.77932
# pegRatio: 2.0
# trailingPegRatio: 1.9505
#            period  strongBuy  buy  hold  sell  strongSell
# symbol row
# INTC   0       0m          5   18    13     3           2
# symbol: INTC
# trailingPE: NA
# forwardPE: 28.070175
# pegRatio: 5.8
# trailingPegRatio: 1.275
#            period  strongBuy  buy  hold  sell  strongSell
# symbol row
# CSCO   0       0m          8   11     8     0           0
# symbol: CSCO
# trailingPE: 15.132931
# forwardPE: 13.723288
# pegRatio: 2.45
# trailingPegRatio: 3.0738
#            period  strongBuy  buy  hold  sell  strongSell
# symbol row
# AMD    0       0m          5    6    15     4           1
# symbol: AMD
# trailingPE: 1269.091
# forwardPE: 41.179943
# pegRatio: 4.99
# trailingPegRatio: 1.9471
